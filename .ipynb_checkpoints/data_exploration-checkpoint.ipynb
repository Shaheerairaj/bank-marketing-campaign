# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns

# %%
df = pd.read_csv("Data/bank-full.csv", delimiter=";")
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# ## Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
fig, ax = plt.subplots(figsize=(12,10))
df.hist(['age','balance','campaign','pdays','duration'], ax=ax)
plt.show();
# Out:
# <ipython-input-12-9870982ff77d>:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df.hist(['age','balance','campaign','pdays','duration'], ax=ax)

# %%
df_cat_cols = ['job','marital','education','default','housing','loan','contact','month','day','previous']

# Create subplots with two columns
fig, axes = plt.subplots(nrows=len(df_cat_cols), ncols=2, figsize=(16, 5 * len(df_cat_cols)))

# Plot graphs for each column in the first column of the subplot
for i, col in enumerate(df_cat_cols):
    counts = df.groupby([col,'y']).size()
    total_counts = df.groupby(col).size()
    percentages = counts.div(total_counts, level=col).unstack(fill_value=0) * 100
    percentages.plot(kind='bar', stacked=True, ax=axes[i, 0])
    axes[i, 0].set_title(f'Graph for {col}')
    axes[i, 0].set_ylabel('Percentage %')

    # Plot graphs for each column filtered by 'y' == 'yes' in the second column of the subplot
    df[df['y'] == 'yes'].groupby([col])['y'].count().sort_values(ascending=False).plot(kind='bar', stacked=True, ax=axes[i, 1])
    axes[i, 1].set_title(f'Graph for {col} (y = yes)')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
df_yes = df[df['y'] == 'yes']
df_yes.groupby(['job'])['y'].count().sort_values(ascending=False)/len(df_yes['y'])*100
# Out:
# job
# management       24.598223
# technician       15.882019
# blue-collar      13.386273
# admin.           11.930422
# retired           9.756098
# services          6.976744
# student           5.086028
# unemployed        3.819247
# self-employed     3.535640
# entrepreneur      2.325581
# housemaid         2.060881
# unknown           0.642844
# Name: y, dtype: float64

# %%
month_to_numeric = {
    'jan': 1, 'feb': 2, 'mar': 3, 'apr': 4, 'may': 5, 'jun': 6,
    'jul': 7, 'aug': 8, 'sep': 9, 'oct': 10, 'nov': 11, 'dec': 12
}

# Create a new column "month_numeric" based on the mapping
df['month_numeric'] = df['month'].map(month_to_numeric)

df['date'] = '2011-' + df['month_numeric'].astype(str) + '-' + df['day'].astype(str)
df['date'] = pd.to_datetime(df['date'])
df['day_of_week'] = df['date'].dt.strftime('%A')

# %%
df.groupby(['day_of_week','y']).size().unstack(fill_value=0).plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='day_of_week'>

# %% [markdown]
# Seems that the campaign was less likely to succeed if done during the early part of the week.
# Monday and Tuesday look to be particularly bad days as compared to the rest.

# %%
plt.figure(figsize=(16,6))
# df.groupby(['date','y']).size().unstack(fill_value=0).plot(kind='bar', stacked=True)
bar_plot = df.groupby(['date','y']).size().unstack(fill_value=0)
plt.bar(bar_plot.index, bar_plot['yes'].values)
# plt.xticks([])
plt.tight_layout()
plt.show()

# %%
df[df['y'] == 'yes'].groupby(['month','month_numeric','y']).size().unstack().sort_values(by='month_numeric').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='month,month_numeric'>

# %% [markdown]
# The summer months seem to be where the time where campaign would succeed the most

# %% [markdown]
# We also see that an overwhelming number of people had submitted a term deposit on the campaign done on the 15th of May.

# %% [markdown]
# For some context, I found the following article which states that portugal in 2011-05-13 when into a double-dip recession after the economy contracts by 0.7% in the first quarter of 2011.

# %% [markdown]
# https://www.onthisday.com/countries/portugal

# %% [markdown]
# It would make sense why so many people would have wanted to put their money into a savings account with a fixed rate of interest. This is probably why the campaigns have been so successfull in the coming 4 months.

# %% [markdown]
# So a good amrketing strategy is probably take advantage of people during a recession.

# %%
df_num_cols = ['age','balance','campaign','pdays','duration']

for col in df_num_cols:
    if col == 'pdays':
        df[df[col] >= 0][[col,'y']].groupby('y').boxplot()
    else:
        df[[col,'y']].groupby('y').boxplot();

# %% [markdown]
# Some other interesting findings:
#
# 1. People older in age were most likely to subscribe to a term deposit
# 2. There is a higher likelyhood of the client submitting a term deposit if they have a higher avg yearly balance
# 3. The less number of days that pass between the previous and current campaign, the more likely the client is to submit a term deposit
# 4. If the client was contacted for a longer duration in the previous campaign, the more likely they are to submit a term deposit.

# %%
df['y'].value_counts()/len(df['y'])*100
# Out:
# no     88.30152
# yes    11.69848
# Name: y, dtype: float64

# %% [markdown]
# ### Summary of Findings:
#
# Relationship of dependant variable with categorical variables:
# 1. There is an overwhelming majority of people who didn't say yes (yes - 11.7% / no - 88.3%)
# 2. Although clients who are in management or technicians seem to be the ones who said yes the most, as a percentage of total people contacted, students and retired people were the most likely to submit a term deposit
# 3. People contacted via cellular were more likely to say yes
# 4. People were drastically more likely to say yes the very first time they were contacted
# 5. There seem to be the most positive responses in May, but as a percentage of total people contacted in that month, it doesn't seem to be the highest. As a percentage, the highest yielding months were December, October and March.
# 6. People without a loan, house or have not been defaulting on their credit are more likely to submit a term deposit
# 7. Thursday to Sunday seem to be good days of the week where we receive positive reponses
# 8. People are more likely to submit a term deposit in the summer months
#
# Relationship of dependant variable with numerical variables:
# 1. People older in age were most likely to subscribe to a term deposit
# 2. There is a higher likelyhood of the client submitting a term deposit if they have a higher avg yearly balance
# 3. The less number of days that pass between the previous and current campaign, the more likely the client is to submit a term deposit
# 4. If the client was contacted for a longer duration in the previous campaign, the more likely they are to submit a term deposit.

# %% [markdown]
# ### Marketing Strategies

# %% [markdown]
# ### 1. Loyalty Programs for Previous Customers
# Deploy loyalty programs and discount offers for customers who had said yes to a previous campaign as they are more likely to say yes.

# %% [markdown]
# ### 2. Target Colleges and Retirment Homes
# Although people with management and blue-collar jobs were the highest ranked in successful campaigns, as a percentage of people contacted per type of job, students and retired people were the most likely to put their money into a savings account.

# %% [markdown]
# ### 3. Structure Regular Brief Calls with Follow-ups
# The data shows that people are more likely to say yes during a call, and mostly during first call if it is for a shorter duration. The elevator pitch should be optimized to give the most useful information to customers within the shortest period of time.

# %% [markdown]
# ### 4. Take Advantage of Socio-Economic Factors
# We've seen that there was an abnormal increase in successful campaigns during Sunday the 15th of May which as stated by the article below, was due to a recession being announed in the media on Friday the 13th of May. Campaigns done shortly after the announcement of significant socio-economic changes are more likely to recieve a positive response out of the fear of clients losing their money elsewhere.
